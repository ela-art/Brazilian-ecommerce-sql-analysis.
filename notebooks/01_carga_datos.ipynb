# %%
import pandas as pd
from sqlalchemy import create_engine
import os
# %pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os; print(os.getcwd()); print(os.listdir("../data/raw/"))
# Out:
# c:\Users\elaru\OneDrive\Desktop\proyectos_personales\proyecto_sql\notebooks
# ['olist_customers_dataset.csv', 'olist_geolocation_dataset.csv', 'olist_orders_dataset.csv', 'olist_order_items_dataset.csv', 'olist_order_payments_dataset.csv', 'olist_order_reviews_dataset.csv', 'olist_products_dataset.csv', 'olist_sellers_dataset.csv', 'product_category_name_translation.csv']

# %%
engine = create_engine(
    "mysql+pymysql://root:admin1234@localhost/olist_db"
)

# %%
pd.read_sql("SELECT 'conexión exitosa' AS mensaje", engine)
# Out:
#             mensaje
# 0  conexión exitosa

# %%
data_path = data_path = "../data/raw/"

for file in os.listdir(data_path):
    if file.endswith(".csv"):
        table_name = file.replace(".csv", "")
        df = pd.read_csv(os.path.join(data_path, file))
        df.to_sql(
            name=table_name,
            con=engine,
            if_exists="replace",
            index=False
        )
        print(f"✓ {table_name} — {len(df)} filas cargadas")
# Out:
# ✓ olist_customers_dataset — 99441 filas cargadas
# ✓ olist_geolocation_dataset — 1000163 filas cargadas
# ✓ olist_orders_dataset — 99441 filas cargadas
# ✓ olist_order_items_dataset — 112650 filas cargadas
# ✓ olist_order_payments_dataset — 103886 filas cargadas
# ✓ olist_order_reviews_dataset — 99224 filas cargadas
# ✓ olist_products_dataset — 32951 filas cargadas
# ✓ olist_sellers_dataset — 3095 filas cargadas
# ✓ product_category_name_translation — 71 filas cargadas
